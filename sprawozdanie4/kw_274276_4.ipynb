# %% [markdown]
# # Sprawozdanie
#
# ## K-Średnich
#
# ### Krzysztof Wiśniewski
#
# Kod k-średnich jest dostępny w całej okazałości na [GitHubie](https://github.com/Argmaster/optmath),
# Załączony do maila optmath-22.5.31-py3.9-none-any.whl to archiwum zip, więc jego zawartość również można łatwo podejrzeć.
# Aby zainstalować załączony pakiet wystarczy użyć komendy
#
# ```
# pip install optmath-22.5.31-py3.9-none-any.whl
# ```
#
# Minimal Python version required: 3.9

# %%
from kw_274276_4 import Session

session = Session("mm_data.csv")

# %% [markdown]
# K-średnich jest metodą grupowania danych wielowymiarowych poprzez przypisywanie obiektów do K grup (klastrów) na podstawie minimalnej odległości od centroidów klastrów.

# %% [markdown]
# # Wykresy pogrupowanych danych
#
# Do grupowania wykorzystane zostały dnane wynikowe z analizy PCA, pozwalającej na redukcję wymiarowości danych. Dane w takim stanie łatwiej jest analizować.

# %%
session.post_pca_kmeans().plot_clusters(size=(24, 16))
# Out:
# Clustering... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# # Wykresy składowych głównych z zaznaczonymi kolorem klasyfikacjami nasion
#
# -   **Blue** - *Çerçevelik*
# -   **Red** - *Ürgüp Sivrisi*
#
# ![alt text](output.png "Seed classification contained in data.")

# %% [markdown]
# # Wnioski
#
# Wyniki analizy K-średnich nie pozwalają na wyciągnięcie wniosków na temat cech fizycznych nasion innch niż zależności matematyczne.
#
# Ponieważ wszystkie obiekty znajdują się w jednym wyraźnym skupieniu, a powstające klastry zdają się nie wskazywać na żadne istotne tendencje w jego obrębie.
#
# Porównując klastry wynikowe K-średnich do znanej (obecnej w danych) klasyfikacji nasion na gatunki można zauważyć częściową zbierzność tych grupowań.
#
# Tymsamym można rozwarzyć potencjał tej metody jako narzędzia do wstępnego rozrużniania nasion o nieznanym pochodzeniu.
